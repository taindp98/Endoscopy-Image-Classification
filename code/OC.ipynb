# %%
# %load_ext autoreload
# %autoreload 2

# %%
# !pip install fastai==1.0.61

# %%
# !pip install timm

# %%
# !pip show einops

# %%
from fastai.vision import *
from fastai.callbacks.hooks import *
from PIL import Image
import os
from glob import glob
import cv2
from tqdm import tqdm
import multiprocessing as mp
import pandas as pd
from matplotlib import pyplot as plt
from torchvision import transforms
import timm

# from torch.utils.data import DataLoader, RandomSampler, SequentialSampler
import torch.nn.functional as F

# %%
from utils import interleave, de_interleave, show_batch, AverageMeter, show_grid, get_config
from learner import SemiSupLearning, SupLearning
from dataset import get_data
from build import build_model

# %%
# config = get_config('./configs/local_semisupervised_mock_groupbycat.yaml')
config = get_config('./configs/local_supervised.yaml')

# %%
df_anno = pd.read_csv(config['DATA']['ANNO'])
df_unanno = None
df_anno.head()
# Out:
#    index                                              image  target  is_valid
# 0   7868  lower-gi-tract/quality-of-mucosal-views/bbps-2...       0     False
# 1   8674  lower-gi-tract/quality-of-mucosal-views/bbps-2...       0     False
# 2   2923  lower-gi-tract/anatomical-landmarks/cecum/12fc...       0     False
# 3   4818  lower-gi-tract/quality-of-mucosal-views/bbps-2...       0     False
# 4   6224  lower-gi-tract/quality-of-mucosal-views/impact...       0     False

# %%
train_dl, valid_dl = get_data(config, df_anno, df_unanno, is_visual=True)

# %%
model = timm.create_model(config.MODEL.NAME, pretrained=True, num_classes = 2)

# %%
# model

# %%
fts.shape
# Out:
# torch.Size([8, 2048])

# %%
features = []
gts = []
for x, y in tqdm(train_dl):
    fts = backbone(x)
    features += fts
    gts += y
# Out:
#   9%|█████▌                                                      | 98/1067 [03:15<32:16,  2.00s/it]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-52-8dee33156e55> in <module>
#       2 gts = []
#       3 for x, y in tqdm(train_dl):
# ----> 4     fts = backbone(x)
#       5     features += fts
#       6     gts += y
#
# ~\anaconda3\envs\cls\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~\anaconda3\envs\cls\lib\site-packages\torch\nn\modules\container.py in forward(self, input)
#     139     def forward(self, input):
#     140         for module in self:
# --> 141             input = module(input)
#     142         return input
#     143
#
# ~\anaconda3\envs\cls\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~\anaconda3\envs\cls\lib\site-packages\torch\nn\modules\container.py in forward(self, input)
#     139     def forward(self, input):
#     140         for module in self:
# --> 141             input = module(input)
#     142         return input
#     143
#
# ~\anaconda3\envs\cls\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~\anaconda3\envs\cls\lib\site-packages\timm\models\resnet.py in forward(self, x)
#     427
#     428         if self.downsample is not None:
# --> 429             shortcut = self.downsample(shortcut)
#     430         x += shortcut
#     431         x = self.act3(x)
#
# ~\anaconda3\envs\cls\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~\anaconda3\envs\cls\lib\site-packages\torch\nn\modules\container.py in forward(self, input)
#     139     def forward(self, input):
#     140         for module in self:
# --> 141             input = module(input)
#     142         return input
#     143
#
# ~\anaconda3\envs\cls\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~\anaconda3\envs\cls\lib\site-packages\torch\nn\modules\conv.py in forward(self, input)
#     444
#     445     def forward(self, input: Tensor) -> Tensor:
# --> 446         return self._conv_forward(input, self.weight, self.bias)
#     447
#     448 class Conv3d(_ConvNd):
#
# ~\anaconda3\envs\cls\lib\site-packages\torch\nn\modules\conv.py in _conv_forward(self, input, weight, bias)
#     441                             _pair(0), self.dilation, self.groups)
#     442         return F.conv2d(input, weight, bias, self.stride,
# --> 443                         self.padding, self.dilation, self.groups)
#     444
#     445     def forward(self, input: Tensor) -> Tensor:
#
# RuntimeError: [enforce fail at ..\c10\core\CPUAllocator.cpp:76] data. DefaultCPUAllocator: not enough memory: you tried to allocate 8388608 bytes.

# %%
model = build_model(config)
# Out:
# C:\Users\Admin\anaconda3\envs\cls\lib\site-packages\torch\functional.py:445: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ..\aten\src\ATen\native\TensorShape.cpp:2157.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]

# %%
if torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')

# %%
if config.TRAIN.IS_SSL:
    classifier = SemiSupLearning(model = model,
                          opt_func=config['TRAIN']['OPT_NAME'], 
                          device = device)
else:
    classifier = SupLearning(model = model,
                          opt_func=config['TRAIN']['OPT_NAME'], 
                          device = device)
classifier.get_dataloader(train_dl, valid_dl)
classifier.get_config(config)

# %%
# for x, y in train_dl:
#     break
# model(x)

# %%
# classifier.load_checkpoint('D:\\model\\endoscopy\\hyper_kvasir\\sup_resnet50\\05_31_2022_17_33_39_ce.pth')

# %%
classifier.fit()
# Out:
# Training epoch: 1 | Current LR: 0.000050
#   0%|▏                                                 | 3/1000 [00:07<44:08,  2.66s/it, loss=2.54]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-1e52701ef5b5> in <module>
# ----> 1 classifier.fit()
#
# ~\working\python\mine\endoscopic\code\learner.py in fit(self)
#     514             self.epoch = epoch
#     515             print(f'Training epoch: {self.epoch} | Current LR: {self.optimizer.param_groups[0]["lr"]:.6f}')
# --> 516             train_loss = self.train_one(self.epoch)
#     517             print(f'\tTrain Loss: {train_loss.avg:.3f}')
#     518             if (epoch)% self.config.TRAIN.FREQ_EVAL == 0:
#
# ~\working\python\mine\endoscopic\code\learner.py in train_one(self, epoch)
#     379             self.optimizer.zero_grad()
#     380
# --> 381             losses.backward()
#     382             self.optimizer.step()
#     383             self.lr_scheduler.step_update(epoch * num_steps + step)
#
# ~\anaconda3\envs\cls\lib\site-packages\torch\_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     305                 create_graph=create_graph,
#     306                 inputs=inputs)
# --> 307         torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#     308
#     309     def register_hook(self, hook):
#
# ~\anaconda3\envs\cls\lib\site-packages\torch\autograd\__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     154     Variable._execution_engine.run_backward(
#     155         tensors, grad_tensors_, retain_graph, create_graph, inputs,
# --> 156         allow_unreachable=True, accumulate_grad=True)  # allow_unreachable flag
#     157
#     158
#
# KeyboardInterrupt:

# %%
# classifier.save_checkpoint('./')
